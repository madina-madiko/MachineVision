# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
import numpy as np

image1 = pltimg.imread('.\\Super.jpg') 
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(image1[:,:,0]) 
plt.subplot(222)
plt.imshow(image1) 
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
import numpy as np
from PIL import Image
img = Image.open(".\\Super.jpg")
fig = plt.figure(figsize=(10,10))

area = (5, 5, 5, 5)
plt.subplot(223)
plt.imshow(image1.crop(area)) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a0bd58fd74ac> in <module>()
#       9 area = (5, 5, 5, 5)
#      10 plt.subplot(223)
# ---> 11 plt.imshow(image1.crop(area))
#      12 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'crop'
