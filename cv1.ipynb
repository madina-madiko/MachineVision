# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(im[:,:,[0,1,2]])
plt.subplot(222)
plt.imshow(im[:,:,[1,2,0]])
plt.subplot(223)
plt.imshow(im[:,:,[0,2,1]])
plt.subplot(224)
plt.imshow(im[:,:,[2,0,1]])
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
img = Image.open(".\\Super.jpg")
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
area = (750, 60, 1100, 600)
cat_head = img.crop(area)
plt.imshow(cat_head)
plt.show()

# %%
from PIL import Image
img = Image.open(".\\6_26.jpg")
area = (900, 300, 1170, 600)
cat_head = img.crop(area)
img1 = Image.open(".\\6_26.jpg")
img1.paste(cat_head,(500,500))
img1.show()
