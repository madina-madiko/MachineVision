# %%
from scipy import ndimage as nimg
import numpy as np
gflt = nimg.gaussian_filter(imlen, sigma=5)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(gflt,cmap='gray')
plt.subplot(132)
plt.imshow(imlen,cmap='gray')
plt.subplot(133)
plt.imshow((imlen-gflt),cmap='gray')

# %%
from scipy import ndimage as nimg
import numpy as np
mflt = nimg.median_filter(imlen, 5)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(mflt,cmap='gray')
plt.subplot(132)
plt.imshow(imlen,cmap='gray')
plt.subplot(133)
plt.imshow((imlen-mflt),cmap='gray')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import math
from scipy import ndimage as nimg
import numpy as np
gflt = nimg.gaussian_filter(imbook, sigma=20)
fig = plt.figure(figsize=(15,10))
plt.subplot(141)
plt.imshow(imbook,cmap='gray')
plt.subplot(142)
plt.imshow(gflt,cmap='gray')
plt.subplot(143)
plt.imshow((imbook-gflt),cmap='gray')
result = imbook-gflt
maxi=result.max()
print(maxi)
mini=result.min()
print(mini)
plt.subplot(144)
plt.imshow(((result-mini)/(maxi-mini)))
# Out:
# 0.728547
# -0.827387
